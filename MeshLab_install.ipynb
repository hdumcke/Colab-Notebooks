# %% [markdown]
# # Install Meshroom to your Google Drive

# %% [markdown]
# ## Mount your Google Drive
#
# Paste your authorisation code and resume with Enter

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## Get a binary version of Meshroom

# %%
# %cd /content
# !mkdir temp
# !mkdir meshroom

# %cd temp
# !wget -N https://github.com/alicevision/meshroom/releases/download/v2021.1.0/Meshroom-2021.1.0-linux-cuda10.tar.gz
# !tar -xvf Meshroom-2021.1.0-linux-cuda10.tar.gz -C ../meshroom

# %% [markdown]
# ## Copy Meshroom to your Google Drive

# %%
# !cp -r /content/meshroom "/content/drive/My Drive/
