# %% [markdown]
# ## Render a Blender file

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !wget https://download.blender.org/release/Blender2.93/blender-2.93.2-linux-x64.tar.xz

# %%
# !tar -xf blender-2.93.2-linux-x64.tar.xz

# %%
# !sudo ./blender-2.93.2-linux-x64/blender  -b "/content/drive/My Drive/Colab Notebooks/example.blend" -noaudio -P "/content/drive/My Drive/Colab Notebooks/enable_gpu.py" -E 'CYCLES' -f 1 -F 'PNG'
