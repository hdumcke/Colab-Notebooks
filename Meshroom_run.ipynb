# %% [markdown]
# # Install Meshroom to your Google Drive

# %% [markdown]
# ## Mount your Google Drive
#
# Paste your authorisation code and resume with Enter

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## Set Path for Data Set

# %%
# %env DATA=gerrard-hall/images

# %% [markdown]
# ## Install Meshroom

# %%
# %cd /content
# !mkdir Meshroom
# !tar -xvf "/content/drive/My Drive/Meshroom-2021.1.0-linux-cuda10.tar.gz" -C Meshroom

# %% [markdown]
# ## Run Meshroom on Data Set

# %%
# !mkdir -p "/content/drive/My Drive/$DATA/out"

# !/content/Meshroom/Meshroom-2021.1.0-av2.4.0-centos7-cuda10.2/meshroom_batch --input "/content/drive/My Drive/$DATA" --output "/content/drive/My Drive/$DATA/out"
# !rm -rf "/content/drive/My Drive/$DATA/MeshroomCache"
# !cp -r /tmp/MeshroomCache "/content/drive/My Drive/$DATA/"
